# %%
import pandas as pd
import numpy as np

# %%
# Read transposed csv
arma3t = pd.read_csv('./arma3.csv', header=None).T

# %%
#arma2_np = arma2t.to_numpy()
print(arma3t.shape)
# Out:
# (100, 10000)

# %%
# List of timestamp to insert
# Change period according to length of the time series
datelist = pd.date_range(start='1/1/2022', freq='1H', tz='UTC', periods=100)
#print(type(datelist))

# Insert timestamp as the first column to transposed csv
arma3t.insert(0, "Timestamp", datelist)

# %%
arma3t.head()
# Out:
#                   Timestamp         0         1         2         3         4  \
# 0 2022-01-01 00:00:00+00:00  1.290113 -1.437362  1.233126 -3.392760  0.017429
# 1 2022-01-01 01:00:00+00:00 -0.101551  4.983675  0.518587 -1.028727 -2.609596
# 2 2022-01-01 02:00:00+00:00  0.850492  0.491726  1.161417 -6.042771  0.405186
# 3 2022-01-01 03:00:00+00:00  0.470221 -2.639452 -4.066286 -1.582325  2.090611
# 4 2022-01-01 04:00:00+00:00  1.321633 -0.021719 -0.996588  0.706295  1.620615
#
#           5         6         7         8  ...      9990      9991      9992  \
# 0 -1.987211  1.658968  1.390632  0.886643  ...  1.154253 -0.591451 -0.105589
# 1 -0.440477 -0.876729  0.788696 -0.115121  ...  1.931420  0.424407  0.689468
# 2  1.395835  0.430881 -4.892176 -0.860982  ... -2.974188 -1.135193 -0.791842
# 3 -3.098295 -0.733541 -0.272307  0.451894  ...  0.426457 -0.072974  2.764271
# 4  1.319547 -1.625361  0.898360  0.580711  ...  0.256663  2.079452  0.728685
#
# ...

# %%
# Write dataframe to csv
arma3t.to_csv('arma3.csv', index=False)
